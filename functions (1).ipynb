# %% [markdown]
# QUESTION NO-1 Define the role of a Data Analyst in your own words.
#                 What value do they bring to an organization?
#
#  ANSWER - The role of data analyst -:
#           - a data analyst collect the data to help an organization make better decisions.the data analyst using the tools excel,sql,power bi,python,etc.to find trend pattern and insight. the data analyst main thing is a understand the business problem and solve the problem. this is a main role of data analyst.
#          1] data collection - collect the information on different sources
#          2]data cleaning -collect the unstructured data and using the tools
#            crete the sturctured data,
#          3] data analysis - collecting the data organise the data to crete mening full paterned
#
#
#
#
# QUESTION NO-2 List three tools commonly used by Data Analysts and explain what
#               each is mainly used for ?
#
#  ANSWER  -  The data analyst commonly using tools following there-
#
#             1] microsoft excel the use for data entry,cleaning the data,formulas
#             and pivot table etc.  microsoft is a spredshift software ,create the chart. in which using the formula like a sum,avarage,vlookeup etc.
#
#             2}SQL manage the data in database ,summurice the data in large data set.its help to data analyst in store the data ,and anlysis the data
#
#             3]power bi is a data visualization tools and business inteligence tools in which crete a chart,and graf.use to importing the data cleaning the data analysis
#             power mainly use on data analysis,design and graphics.
#
#
#
#
# QUESTION NO-3 Write the end-to-end analytics workflow in the correct
#               order and briefly explain each step.
#
#  ANSWER  -   1] defind the problem - clear understand the data whats business
#              problem   ,what happened .
#              exa- why sales decresed in last month
#
#              2]collect the data- collect the data verious source
#
#              3] clening the data-deleting the errors ,dublicate data, missing value
#              4]data analysis- using the methods,formulas,and predict the data to inside the data, using tools
#              5] data analysis- create a graph,and dashbord, easy to understand data
#              6]insight- understand the result to get something structured dataa
#              7]decision making - share finding data  to stake holder. use to improving business performance
#
#
#
#  QUESTION NO-4  What is Prompt Engineering, and explain any two types of
#                 prompts used in Generative AI ?
#
#    ANSWER -  Prompt Engineering is the process of designing and optimizing text
#              ansd design. helps in guiding the Ai  behavior ensuring that the model understands the intent behind the user  request. Understanding how AI interprets language, Writing clear and specific prompt
#
#             - types of prompt engineering -
#
#              1] instruction base prompt-An instruction-based prompt is when you clearly tell the AI what you want it to do  by giving it a direct instruction or command.
#
#              2] few short prompt- A few-shot prompt is when you show the AI a few examples of how a task should be done before asking it to generate a new response.
#
#
#
# QUESTION NO-5   What are the key differences between a Business Analyst
#              and Data Analyst in terms of roles, responsibilities, and focus?
#
#   ANSWER -   different between a business analyst and data analyst-:
#              A Business Analyst focuses on understanding business needs,      improving processes, and finding solutions to help an organization    achieve its goals.
#
#             - A Data Analyst focuses on collecting, organizing, analyzing, and interpreting data to help the business make data-driven decisions.
#
#              roles and responsibility-:  business analyst
#              -  A Business Analyst acts  a bridge between business teams and    technical teams. identify problems or opportunities and suggest strategic or process improvements to achieve organizational goals.
#
#              Involves defining and aligning business goals with actionable plans to       meet evolving organizational needs.
#
#            -   improve productivity and consistency across the organization
#
#               roles and responsibility-: data analyst
#
#              - A Data Analyst focuses on working with data collecting cleaning analysis, and visualizing to help the business make data-driven decision. collect, clean, and analyze data to find patterns and create reports that help organizations make informed decisions.
#
#               collecting raw data from various sources, verifying its accuracy, and cleaning it by removing error.
#
#               Create customized reports,dashboards,and visualizations to present findings clearly and consist stakeholders
#
#
# QUESTION NO 6  Explain any three AI-powered ETL (Extract, Transform, Load)
#                tools and how they are used in analytics ?
#
#  ANSWER -      ETL stands for Extract, Transform and load . Extracting data
#                different sources,Transforming it into a usable format,
#                Loading it into a data warehouse or analytics system.
#
#               use in analytics -:
#               Helps organizations combine large amounts of data.
#               high-quality, accurate, and clean data.
#               learning and transforming raw data into structured formats ready for analysis.Providing clean, unified datasets for advanced data  modeling  Ensuring real-time data availability for tools like Power BI, Tableau, or Python-based analytics
#               Feeding high-quality, trusted data into analytics platforms for accurate insights.
#
#
#
# QUESTION NO 7  Give three applications of Data Analytics across different
#                industries and explain how it creates value ?
#
#  ANSWER -:1. Healthcare Industry Predictive Analytics for Patient Care.
#              Hospitals and healthcare providers use predictive analytics to analyze patient data, medical histories, and lab results
#              which patients are at high risk for conditions like diabetes or heart disease based on lifestyle, genetic, and historical data.
#              Early Diagnosis Enables doctors to detect diseases before symptoms appear.Reduces hospital readmissions and unnecessary treatments.
#
#             2. Retail Industry Customer Behavior and Recommendation Analytics
#              Retail Comapany use customer analytics to study buying patterns, preferences, and feedback to improve marketing and sales strategies.E-commerce platforms like Amazon use data analytics to recommend products based on past purchases, search history
#
#             Increased Sales Personalized recommendations boost conversion rates.
#
#             3. Banking & Finance Industry  Fraud Detection and Risk Management
#
#               Banks use data analytics and machine learning to detect fraudulent activities and assess credit risks in real-time.
#
#             Analytics models analyze transaction patterns to detect anomalies that may indicate fraud.
#             Fraud Prevention  Protects customers and reduces financial losses.
#             Customer Trust Builds confidence through secure and transparent operations.
#
#
#
# QUESTION NO 8   Explain the evolution of analytics, highlighting the different
#                 Stages from Descriptive to Generative AI.
#
#   ANSWER  -:   Data analytics has evolved over time from simple data reporting
#                to advanced, AI-driven decision-making.how organizations use data to understand the past, predict the future, and generate intelligent insights.
#            1   Descriptive Analytics   What Happened
#               Descriptive analytics focuses on summarizing historical data to understand what has already occurred
#               Customer purchase patterns
#               Tools: Microsoft Excel
#
#             2  Diagnostic Analytics   Why Did It Happen
#               Diagnostic analytics digs deeper into data to find causes and relationships behind past outcomes.
#               Analyzing customer churn reasons
#             3 Predictive Analytics  What Will Happen
#              Predictive analytics uses statistical models and machine learning to forecast future outcomes based on historical data.
#              Predicting product demand for the next quarter.
#
#            4 Prescriptive Analytics  What Should We Do
#            Prescriptive analytics recommends the best course of action using optimization
#            Optimization models, simulation, reinforcement learning
